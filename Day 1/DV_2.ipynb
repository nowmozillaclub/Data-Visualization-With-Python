# %% [markdown]
# # **Data Visualization using Python**
# ## **Organized by NOW Mozilla Club in Collaboration with Computer Engineering Department**
#
# ## **Instructor**: Radhika Chapaneri
#
# ## May 2020

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Basic plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from math import pi
x = None
y = None

plt.None
plt.grid()
plt.show()

# %%
from math import pi
x = np.linspace(-pi, pi, 200)
y = None
z = None

plt.None
plt.None
plt.legend(['sin','cos'])
plt.grid()
plt.show()

# %%
from math import pi
x = np.linspace(-pi, pi, 200)
y = None
z = None

plt.None(None, None, color='k', linestyle='--', linewidth=3, marker='.')
plt.None(None, None, color='r', linestyle='-', marker='o')
plt.legend(['sin','cos'])
plt.grid()
plt.show()

# %%
y = None

plt.None
plt.grid()
plt.show()
plt.savefig('exp.png')

# %% [markdown]
# ## Subplots

# %%
x = np.linspace(-1.4, 1.4, 50)

plt.None(2, 2, 1)  # top left
plt.None
plt.grid()

plt.None(2, 2, 2)  # top right
plt.None
plt.grid()

plt.None(2, 2, 3)  # bottow left
plt.None
plt.grid()

plt.None(2, 2, 4)  # bottom right
plt.None
plt.grid()
plt.show()

# %% [markdown]
# ## **Histograms**

# %%
# Histogram of Age
x = [1,1,2,3,3,5,7,8,9,10,10,11,11,13,13,15,16,17,18,18,18,19,20,21,21,23,24,
     24,25,25,25,25,26,26,26,27,27,27,27,27,29,30,30,31,33,34,34,34,35,36,
     36,37,37,38,38,39,40,41,41,42,43,44,45,45,46,47,48,48,49,50,51,52,53,54,
     55,55,56,57,58,60,61,63,64,65,66,68,70,71,72,74,75,77,81,83,84,87,89,
     90,90,91]

plt.None(None, bins=None, rwidth = None)
plt.None(axis='y',alpha=0.5) 
plt.xlabel('Age value')
plt.ylabel('Frequency')
plt.title('My first histogram')
plt.show()

# %%
plt.None(None, bins=None, color = 'green', edgecolor ='black', rwidth = 0.9) 

plt.None(axis='y',alpha=0.5) 
plt.xlabel('Age value')
plt.ylabel('Frequency')
plt.title('My first histogram')
plt.show()

# %% [markdown]
# # **Bar plot**

# %%
counts = None
programme = ('BTechIntegrated', 'MCA', 'BTech')

plt.None(None, None)
plt.xlabel('Programme Type')
plt.ylabel('Count')
plt.title('Distribution')
plt.show()

# %%
counts = [60, 20, 35]
programme = ('BTechIntegrated', 'MCA', 'BTech')
index= None

plt.None(None, None, color = ['red','blue','cyan'])
plt.title('Bar blot of student distribution for workshop')
plt.xlabel('Programme Type')
plt.ylabel('Count')
plt.xticks(index,programme,rotation =90)
plt.show()

# %% [markdown]
# # **Pie chart**

# %%
# Pie chart
slices = [59291, 40000, 47544, 35000, 35917]
labels = ['Javascript', 'HTML/CSS', 'Python', 'SQL', 'Java']

plt.None(None, labels=None)
plt.title('My Pie chart')
plt.show()

# %%
# Pie chart
slices = [59291, 40000, 47544, 35000, 35917]
labels = ['Javascript', 'HTML/CSS', 'Python', 'SQL', 'Java']
explode = [0,0,0.1,0,0]
color=['r','b','g','c','y']

plt.None(None,labels=None,explode=None,startangle=90,autopct='%1.2f%%',colors=color)
plt.title('My Pie chart')
plt.show()

# %% [markdown]
# # **Scatter plot**

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6] # age of car
y = [99,86,87,88,111,86,103,87,94,78,77,85,86] # speed of car

plt.None(None, None, c='red')
plt.title('My scatter plot')
plt.xlabel('Age')
plt.ylabel('Speed')
plt.show()

# %% [markdown]
# # **Boxplot**

# %%
import matplotlib.pyplot as plt
data=[25, 28, 29, 29, 30, 34, 35, 35, 37, 38]

plt.None(None)
plt.title('My Box plot')
plt.xlabel('Age')
plt.show()
