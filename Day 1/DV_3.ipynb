# %% [markdown]
# # **Data Visualization using Python**
# ## **Organized by NOW Mozilla Club in Collaboration with Computer Engineering Department**
#
# ## **Instructor**: Radhika Chapaneri
#
# ## May 2020

# %% [markdown]
# # **Pandas**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing Data

# %%
cars_data = None

# %%
# Output object type
type(None)

# %% [markdown]
# # Understanding and cleaning data

# %% [markdown]
# ### Viewing Data

# %%
cars_data.None

# %%
# Output entire Data Frame
None

# %% [markdown]
# * To get the column labels of the dataframe.

# %%
cars_data.None

# %% [markdown]
# * To get the total number of elements from the
# dataframe

# %%
cars_data.None

# %% [markdown]
# * To get the dimensionality of the dataframe

# %%
cars_data.None

# %%
cars_data.None[4,'FuelType']

# %%
cars_data.None[4,2]

# %% [markdown]
# * To access a group of rows and columns by
# label(s) loc() can be used

# %%
cars_data.None

# %%
# Select all rows for multiple columns 'KM', , 'HP', 'Automatic', 
cars_data.None[None,["KM", "HP", "Automatic"]]

# %% [markdown]
# * iloc() is integer based slicing, whereas .loc() used labels/column names.

# %%
cars_data.None

# %% [markdown]
# * dtypes returns a series with the data type of
# each column

# %%
cars_data.None

# %% [markdown]
# * info() returns a concise summary of a
# dataframe

# %%
cars_data.None

# %% [markdown]
# * unique() is used to find the unique
# elements of a column

# %%
print(np.None(cars_data['KM']))
print(np.None(cars_data['HP']))
print(np.None(cars_data['Doors']))

# %%
cars_data = pd.None('Toyota.csv', None = ["??", "????"])

# %%
cars_data

# %%
cars_data['Doors'].None('three',3, inplace=True)
cars_data['Doors'].None('four',4, inplace=True)
cars_data['Doors'].None('five',5, inplace=True)

# %%
cars_data['Doors'] = cars_data['Doors'].astype('int64')
cars_data['MetColor'] = cars_data['MetColor'].astype('object')
cars_data['Automatic'] = cars_data['Automatic'].astype('object')

# %%
cars_data.None

# %%
cars_data['FuelType'].None

# %%
# dropping null values
cars_data = None

# %%
cars_data.None

# %%
cars_data[None == 'Diesel'].None

# %% [markdown]
# # Visualization begins...

# %%
cars_data.None

# %% [markdown]
# Q. Plot the histogram of kilometer

# %%
plt.None(None, bins=None, color = 'green', edgecolor ='black') 
plt.title('Histogram of Kilometer')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Q. Plot the bar plot of Fuel Types

# %%
counts = list(None)
print(counts)

index = None
print(index)

fueltype=('Petrol','Diesel','CNG')

# %%
plt.None(None, None, color = ['red','blue','cyan'])
plt.title('Bar blot of Fuel Types')
plt.xlabel('Fuel Types')
plt.ylabel('Frequency')
plt.xticks(index,fueltype,rotation =90)
plt.show()

# %% [markdown]
# Q. Plot Scatter plot of Age Vs Price

# %%
plt.None(None, None, c='red')
plt.title('Scatter plot of Age Vs Price')
plt.xlabel('Age(months')
plt.ylabel('Price(Euros)')
plt.show()

# %% [markdown]
# A very powerful feature in Pandas is **groupby**.
#
# - This function allows us to **group together rows that have the same value in a particular column**.
# - Then, we can aggregate this group-by object to compute statistics in each group.

# %%
cars_data.None('FuelType')None

# %%
cars_data.None

# %%
cars_data.groupby('FuelType').None

# %% [markdown]
# Q. Plot the boxplot for the attribute 'Age'

# %%
plt.None(None, 
            notch=False, # box instead of notch shape 
            sym='rs',    # red squares for outliers
            vert=True,   # vertical box aligmnent
            labels = ['Age'])

plt.xlabel('Data')
plt.title('Box plot')
